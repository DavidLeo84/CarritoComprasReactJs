# %% [markdown]
# <a href="https://colab.research.google.com/github/institutohumai/cursos-python/blob/master/CV/7_Modelos_Generativos/GANs.ipynb"> <img src='https://colab.research.google.com/assets/colab-badge.svg' /> </a>

# %% [markdown]
# # Redes generativas adversarias
#
# A lo largo de la mayor parte de este curso, hemos hablado sobre cómo hacer predicciones. De una forma u otra, utilizamos mapeos aprendidos de redes neuronales profundas desde ejemplos de datos hasta etiquetas. Este tipo de aprendizaje se llama **aprendizaje discriminativo**, ya que nos gustaría poder discriminar entre fotos de gatos y fotos de perros. Los clasificadores y los regresores son ejemplos de aprendizaje discriminativo. Y las redes neuronales entrenadas por backpropagation han revolucionado todo lo que creíamos saber sobre el aprendizaje discriminativo en conjuntos de datos grandes y complicados. Las precisiones de clasificación en imágenes de alta resolución han pasado de ser inútiles a niveles humanos (con algunas salvedades) en solo 5 o 6 años. Le ahorraremos otra perorata sobre todas las demás tareas discriminatorias en las que las redes neuronales profundas funcionan asombrosamente bien.
#
# Pero hay más en el aprendizaje automático que simplemente resolver tareas discriminatorias. Por ejemplo, dado un gran conjunto de datos, sin etiquetas, podríamos querer aprender un modelo que capture de manera concisa las características de estos datos. Dado tal modelo, podríamos **muestrear** ejemplos de datos sintéticos que se asemejen a la distribución de los datos de entrenamiento. Por ejemplo, dado un gran corpus de fotografías de rostros, es posible que queramos poder generar una nueva imagen fotorrealista que parezca plausible que provenga del mismo conjunto de datos. Este tipo de aprendizaje se llama **modelado generativo**.

# %% [markdown]
# Hasta hace poco, no teníamos ningún método que pudiera sintetizar nuevas imágenes fotorrealistas. Pero el éxito de las redes neuronales profundas para el aprendizaje discriminativo abrió nuevas posibilidades. Una gran tendencia en los últimos tres años ha sido la** aplicación de redes profundas discriminatorias para superar desafíos en problemas que generalmente no consideramos como problemas de aprendizaje supervisado**. Los modelos de lenguaje de redes neuronales recurrentes son un ejemplo del uso de una red discriminativa (entrenada para predecir el siguiente carácter) que, una vez entrenada, puede actuar como un modelo generativo.
#
# En 2014, un artículo innovador presentó las redes adversarias generativas (GAN), una nueva forma inteligente de aprovechar el poder de los modelos discriminativos para obtener buenos modelos generativos. En esencia, las GAN se basan en la idea de que un generador de datos es bueno **si no podemos distinguir los datos falsos de los datos reales**. En estadística, esto se denomina prueba de dos muestras: una prueba para responder a la pregunta de si los conjuntos de datos $X=\{x_1,\ldots, x_n\}$ y $X'=\{x'_1,\ldots, x' _n\}$ se extrajeron de la misma distribución. La principal diferencia entre la mayoría de los artículos estadísticos y los GAN es que estos últimos utilizan esta idea de manera constructiva. En otras palabras, en lugar de simplemente entrenar a un modelo para que diga "oiga, estos dos conjuntos de datos no parecen provenir de la misma distribución", usan la [prueba de dos muestras](https://en.wikipedia.org/wiki/Two-sample_hypothesis_testing) para proporcionar señales de entrenamiento a un modelo generativo. Esto nos permite mejorar el generador de datos hasta que genere algo que se asemeje a los datos reales. Como mínimo, necesita engañar al clasificador. Incluso si nuestro clasificador es una red neuronal profunda de última generación.

# %% [markdown]
# ![Imgur](https://i.imgur.com/ya1gA5H.png)

# %% [markdown]
# La arquitectura GAN se ilustra en la figura de arriba.
# Como puede ver, hay dos piezas en la arquitectura GAN: en primer lugar, necesitamos una red que ssea capaz de generar datos que luzcan igual que la cosa real. Si estamos tratando con imágenes, esto necesita generar imágenes. Si se trata de habla, necesita generar secuencias de audio, y así sucesivamente. A esta la llamamos la **red generadora**. El segundo componente es la **red discriminadora**. Intenta distinguir los datos falsos de los reales. Ambas redes compiten entre sí. La red generadora intenta engañar a la red discriminadora. En ese momento, la red discriminadora se adapta a los nuevos datos falsos. Esta información, a su vez, se utiliza para mejorar la red generadora, y así sucesivamente.

# %% [markdown]
# El discriminador es un clasificador binario para distinguir si la entrada $x$ es real (de datos reales) o falsa (del generador). Por lo general, el discriminador genera una predicción escalar $o\in\mathbb R$ para la entrada $\mathbf x$, por ejemplo, usando una capa densa con una sola neurona, y luego aplica la función sigmoidea para obtener la probabilidad predicha $D(\mathbf x) = 1/(1+e^{-o})$. Suponga que la etiqueta $y$ para los datos verdaderos es $1$ y $0$ para los datos falsos. Entrenamos al discriminador para minimizar la pérdida de entropía cruzada, *es decir*,
#
# $$ \min_D \{ - y \log D(\mathbf x) - (1-y)\log(1-D(\mathbf x)) \},$$
#
# Para el generador, primero se extrae algún parámetro $\mathbf z\in\mathbb R^d$ de una fuente de aleatoriedad, *p. ej.*, una distribución normal $\mathbf z \sim \mathcal{N}(0, 1)$ A menudo llamamos $\mathbf z$ como la variable latente. Luego, se aplica una función para generar $\mathbf x'=G(\mathbf z)$. El objetivo del generador es engañar al discriminador para clasificar $\mathbf x'=G(\mathbf z)$ como datos verdaderos, *es decir*, queremos $D( G(\mathbf z)) \approx 1$. En otras palabras, para un discriminador dado $D$, actualizamos los parámetros del generador $G$ para maximizar la pérdida de entropía cruzada cuando $y=0$, *es decir*,
#
# $$ \max_G \{ - (1-y) \log(1-D(G(\mathbf z))) \} = \max_G \{ - \log(1-D(G(\mathbf z))) \}.$$
#
# Si el generador hace un trabajo perfecto, entonces $D(\mathbf x')\approx 1$ por lo que la pérdida anterior se acerca a 0, lo que da como resultado que los gradientes sean demasiado pequeños para hacer un buen progreso para el discriminador. Así que comúnmente minimizamos la siguiente pérdida:
#
# $$ \min_G \{ - y \log(D(G(\mathbf z))) \} = \min_G \{ - \log(D(G(\mathbf z))) \}, $$
#
# que es solo alimentar $\mathbf x'=G(\mathbf z)$ en el discriminador pero dando la etiqueta $y=1$.
#
#
# En resumen, $D$ y $G$ están jugando un juego "minimax" con la función de objetivo integral:
#
# $$min_D max_G \{ -E_{x \sim \text{Data}} log D(\mathbf x) - E_{z \sim \text{Ruido}} log(1 - D(G(\mathbf z)) ) \}.$$
#
#
#
# Muchas de las aplicaciones de GAN están en el contexto de las imágenes. A modo de demostración, nos vamos a contentar con ajustar primero una distribución mucho más sencilla. Ilustraremos lo que sucede si usamos GAN para construir el estimador de parámetros más ineficiente del mundo para un gaussiano. Empecemos.

# %%
# %matplotlib inline
import torch
from torch import nn

# %% [markdown]
# ## Generando algunos datos "reales"
#
# Dado que este será el ejemplo más lamentable del mundo, simplemente generaremos datos extraídos de una gaussiana.

# %%
X = torch.normal(0.0, 1, (1000, 2))
A = torch.tensor([[1, 2], [-0.1, 0.5]])
b = torch.tensor([1, 2])
data = torch.matmul(X, A) + b

# %% [markdown]
# Let's see what we got. This should be a Gaussian shifted in some rather arbitrary way with mean $b$ and covariance matrix $A^TA$.

# %%
from matplotlib import pyplot as plt
plt.scatter(data[:100, 0].detach().numpy(), data[:100, 1].detach().numpy());
print(f'La matriz de covarianza es\n{torch.matmul(A.T, A)}')
# Out:
# La matriz de covarianza es
# tensor([[1.0100, 1.9500],
#         [1.9500, 4.2500]])

# %%
from torch.utils.data import TensorDataset,DataLoader
def load_array(data_arrays, batch_size, is_train=True):
    """Construct a PyTorch data iterator."""
    dataset = TensorDataset(*data_arrays)
    return DataLoader(dataset, batch_size, shuffle=is_train)

batch_size = 8
data_iter = load_array((data,), batch_size)

# %% [markdown]
# ## Generador
#
# Nuestra red generadora será la red más simple posible: un modelo lineal de una sola capa. Esto se debe a que alimentaremos esa red lineal con un generador de datos gaussiano. Por lo tanto, literalmente solo necesita aprender los parámetros para falsificar cosas a la perfección.

# %%
net_G = nn.Sequential(nn.Linear(2, 2))

# %% [markdown]
# ## Discriminador
#
# Para el discriminador seremos un poco más discriminatorios: usaremos un MLP con 3 capas para hacer las cosas un poco más interesantes.

# %%
net_D = nn.Sequential(
    nn.Linear(2, 5), nn.Tanh(),
    nn.Linear(5, 3), nn.Tanh(),
    nn.Linear(3, 1))

# %% [markdown]
# ## Entrenamiento
#
# Primero, definimos una función para actualizar los pesos del Discriminador.

# %%
def update_D(X, Z, net_D, net_G, loss, trainer_D):
    """Actualiza el Discriminador."""
    batch_size = X.shape[0]
    ones = torch.ones((batch_size,), device=X.device)
    zeros = torch.zeros((batch_size,), device=X.device)
    trainer_D.zero_grad()
    real_Y = net_D(X)
    fake_X = net_G(Z)
    # No hace falta calcular los gradientes de `net_G`,
    # le hacemos un detach a su salida
    fake_Y = net_D(fake_X.detach())
    loss_D = (loss(real_Y, ones.reshape(real_Y.shape)) +
              loss(fake_Y, zeros.reshape(fake_Y.shape))) / 2
    loss_D.backward()
    trainer_D.step()
    return loss_D

# %% [markdown]
# El generador se actualiza de manera similar. Aquí reutilizamos la pérdida de entropía cruzada pero cambiamos la etiqueta de los datos falsos de $0$ a $1$.

# %%
def update_G(Z, net_D, net_G, loss, trainer_G):
    """Actualiza el generador."""
    batch_size = Z.shape[0]
    ones = torch.ones((batch_size,), device=Z.device)
    trainer_G.zero_grad()
    # Se podría usar el `fake_X` del `update_D` para ahorrar cálculo
    fake_X = net_G(Z)
    # Recalcular `fake_Y` es necesario ya que `net_D` ya se actualizó en este punto
    fake_Y = net_D(fake_X)
    loss_G = loss(fake_Y, ones.reshape(fake_Y.shape))
    loss_G.backward()
    trainer_G.step()
    return loss_G

# %% [markdown]
# Tanto el discriminador como el generador realizan una regresión logística binaria con la pérdida de entropía cruzada. Usamos a Adam para suavizar el proceso de entrenamiento. En cada iteración, primero actualizamos el discriminador y luego el generador. Visualizamos tanto pérdidas como ejemplos generados.

# %%
#@markdown Código para animación
from IPython import display
import time

class Accumulator:
    """For accumulating sums over `n` variables."""
    def __init__(self, n):
        """Defined in :numref:`sec_utils`"""
        self.data = [0.0] * n

    def add(self, *args):
        self.data = [a + float(b) for a, b in zip(self.data, args)]

    def reset(self):
        self.data = [0.0] * len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

class Timer:
    """Record multiple running times."""
    def __init__(self):
        """Defined in :numref:`sec_minibatch_sgd`"""
        self.times = []
        self.start()

    def start(self):
        """Start the timer."""
        self.tik = time.time()

    def stop(self):
        """Stop the timer and record the time in a list."""
        self.times.append(time.time() - self.tik)
        return self.times[-1]

    def avg(self):
        """Return the average time."""
        return sum(self.times) / len(self.times)

    def sum(self):
        """Return the sum of time."""
        return sum(self.times)

    def cumsum(self):
        """Return the accumulated time."""
        return np.array(self.times).cumsum().tolist()

def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
    """Set the axes for matplotlib.

    Defined in :numref:`sec_calculus`"""
    axes.set_xlabel(xlabel), axes.set_ylabel(ylabel)
    axes.set_xscale(xscale), axes.set_yscale(yscale)
    axes.set_xlim(xlim),     axes.set_ylim(ylim)
    if legend:
        axes.legend(legend)
    axes.grid()


class Animator:
    """For plotting data in animation."""
    def __init__(self, xlabel=None, ylabel=None, legend=None, xlim=None,
                 ylim=None, xscale='linear', yscale='linear',
                 fmts=('-', 'm--', 'g-.', 'r:'), nrows=1, ncols=1,
                 figsize=(7, 5)):
        """Defined in :numref:`sec_utils`"""
        # Incrementally plot multiple lines
        if legend is None:
            legend = []
        #use_svg_display()
        self.fig, self.axes = plt.subplots(nrows, ncols, figsize=figsize)
        if nrows * ncols == 1:
            self.axes = [self.axes, ]
        # Use a lambda function to capture arguments
        self.config_axes = lambda: set_axes(
            self.axes[0], xlabel, ylabel, xlim, ylim, xscale, yscale, legend)
        self.X, self.Y, self.fmts = None, None, fmts

    def add(self, x, y):
        # Add multiple data points into the figure
        if not hasattr(y, "__len__"):
            y = [y]
        n = len(y)
        if not hasattr(x, "__len__"):
            x = [x] * n
        if not self.X:
            self.X = [[] for _ in range(n)]
        if not self.Y:
            self.Y = [[] for _ in range(n)]
        for i, (a, b) in enumerate(zip(x, y)):
            if a is not None and b is not None:
                self.X[i].append(a)
                self.Y[i].append(b)
        self.axes[0].cla()
        for x, y, fmt in zip(self.X, self.Y, self.fmts):
            self.axes[0].plot(x, y, fmt)
        self.config_axes()
        display.display(self.fig)
        display.clear_output(wait=True)

# %%
def train(net_D, net_G, data_iter, num_epochs, lr_D, lr_G, latent_dim, data):
    #Declara la pérdida
    loss = nn.BCEWithLogitsLoss(reduction='sum')
    #Inicializa ambas redes
    for w in net_D.parameters():
        nn.init.normal_(w, 0, 0.02)
    for w in net_G.parameters():
        nn.init.normal_(w, 0, 0.02)
    #Declara los optimizadores
    trainer_D = torch.optim.Adam(net_D.parameters(), lr=lr_D)
    trainer_G = torch.optim.Adam(net_G.parameters(), lr=lr_G)
    #Prepara el graficador de curvas
    animator = Animator(xlabel='epoch', ylabel='loss',
                            xlim=[1, num_epochs], nrows=2, figsize=(5, 5),
                            legend=['discriminator', 'generator'])
    animator.fig.subplots_adjust(hspace=0.3)
    #Comienza a entrenar
    for epoch in range(num_epochs):
        # Entrena una Epoch
        timer = Timer()
        metric = Accumulator(3)  # loss_D, loss_G, num_examples
        for (X,) in data_iter:
            batch_size = X.shape[0]
            Z = torch.normal(0, 1, size=(batch_size, latent_dim))
            metric.add(update_D(X, Z, net_D, net_G, loss, trainer_D),
                       update_G(Z, net_D, net_G, loss, trainer_G),
                       batch_size)
        # Visualiza los ejemplos generados
        Z = torch.normal(0, 1, size=(100, latent_dim))
        fake_X = net_G(Z).detach().numpy()
        animator.axes[1].cla()
        animator.axes[1].scatter(data[:, 0], data[:, 1])
        animator.axes[1].scatter(fake_X[:, 0], fake_X[:, 1])
        animator.axes[1].legend(['real', 'generated'])
        # Muestra las pérdidas
        loss_D, loss_G = metric[0]/metric[2], metric[1]/metric[2]
        animator.add(epoch + 1, (loss_D, loss_G))
    print(f'loss_D {loss_D:.3f}, loss_G {loss_G:.3f}, '
          f'{metric[2] / timer.stop():.1f} examples/sec')

# %% [markdown]
# Ahora especificamos los hiperparámetros para que se ajusten a la distribución gaussiana.

# %%
lr_D, lr_G, latent_dim, num_epochs = 0.05, 0.005, 2, 20
train(net_D, net_G, data_iter, num_epochs, lr_D, lr_G,
      latent_dim, data[:100].detach().numpy())
# Out:
# loss_D 0.686, loss_G 0.717, 2107.0 examples/sec

# %% [markdown]
# # Redes Generativas Adversarias Convolucionales Profundas (DCGAN)
#
# En la sección anterior, presentamos las ideas básicas sobre cómo funcionan las GAN. Mostramos que pueden extraer muestras de una distribución simple y fácil de muestrear, como una distribución uniforme o normal, y transformarlas en muestras que parecen coincidir con la distribución de algún conjunto de datos. Y aunque nuestro ejemplo de hacer coincidir una distribución gaussiana en 2D entendió el punto, no es especialmente emocionante.
#
# En esta sección, demostraremos cómo puede usar GAN para generar imágenes. Basaremos nuestros modelos en las GAN convolucionales profundas (DCGAN) presentadas en [este paper](https://d2l.ai/chapter_references/zreferences.html#id218). Tomaremos prestada la arquitectura convolucional que ha demostrado ser tan exitosa para los problemas discriminativos de visión por computadora y mostraremos cómo se pueden aprovechar a través de las GAN para generar imágenes.

# %% [markdown]
# ## Dataset FIFA

# %% [markdown]
# El conjunto de datos que usaremos es una colección de imágenes de jugadores de futbol profesionales obtenidos de sofifa.com. Primero descarguemos, extraigamos y carguemos este conjunto de datos.

# %%
# !gdown https://drive.google.com/uc?id=1zpT6gHzvbr21_Vq4NjpRY0JGSaQOSANa
# !unzip fifa.zip
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  extracting: Images/550.png
#  extracting: Images/5500.png
#  extracting: Images/5501.png
#  extracting: Images/5502.png
#  extracting: Images/5503.png
#  extracting: Images/5504.png
#   inflating: Images/5505.png
#  extracting: Images/5506.png
#  extracting: Images/5507.png
#  extracting: Images/5508.png
#  extracting: Images/5509.png
#  extracting: Images/551.png
#  extracting: Images/5510.png
#   inflating: Images/5511.png
#  extracting: Images/5512.png
#  extracting: Images/5513.png
#   inflating: Images/5514.png
#  extracting: Images/5515.png
#  extracting: Images/5516.png
#   inflating: Images/5517.png
#  extracting: Images/5518.png
#  extracting: Images/5519.png
#  extracting: Images/552.png
#  extracting: Images/5520.png
#  extracting: Images/5521.png
#  extracting: Images/5522.png
#  extracting: Images/5523.png
#  extracting: Images/5524.png
#  extracting: Images/5525.png
#  extracting: Images/5526.png
#   inflating: Images/5527.png
#  extracting: Images/5528.png
#  extracting: Images/5529.png
#  extracting: Images/553.png
#  extracting: Images/5530.png
#  extracting: Images/5531.png
#  extracting: Images/5532.png
#  extracting: Images/5533.png
#  extracting: Images/5534.png
#  extracting: Images/5535.png
#  extracting: Images/5536.png
#   inflating: Images/5537.png
#   inflating: Images/5538.png
#  extracting: Images/5539.png
#  extracting: Images/554.png
#  extracting: Images/5540.png
#  extracting: Images/5541.png
#  extracting: Images/5542.png
#   inflating: Images/5543.png
#  extracting: Images/5544.png
#  extracting: Images/5545.png
#  extracting: Images/5546.png
#  extracting: Images/5547.png
#   inflating: Images/5548.png
#  extracting: Images/5549.png
#  extracting: Images/555.png
#  extracting: Images/5550.png
#   inflating: Images/5551.png
#  extracting: Images/5552.png
#  extracting: Images/5553.png
#  extracting: Images/5554.png
#  extracting: Images/5555.png
#  extracting: Images/5556.png
#  extracting: Images/5557.png
#   inflating: Images/5558.png
#   inflating: Images/5559.png
#   inflating: Images/556.png
#  extracting: Images/5560.png
#  extracting: Images/5561.png
#  extracting: Images/5562.png
#  extracting: Images/5563.png
#  extracting: Images/5564.png
#  extracting: Images/5565.png
#  extracting: Images/5566.png
#  extracting: Images/5567.png
#  extracting: Images/5568.png
#   inflating: Images/5569.png
#   inflating: Images/557.png
#  extracting: Images/5570.png
#  extracting: Images/5571.png
#   inflating: Images/5572.png
#  extracting: Images/5573.png
#   inflating: Images/5574.png
#  extracting: Images/5575.png
#  extracting: Images/5576.png
#  extracting: Images/5577.png
#  extracting: Images/5578.png
#  extracting: Images/5579.png
#  extracting: Images/558.png
#  extracting: Images/5580.png
#   inflating: Images/5581.png
#  extracting: Images/5582.png
#  extracting: Images/5583.png
#  extracting: Images/5584.png
#   inflating: Images/5585.png
#   inflating: Images/5586.png
#   inflating: Images/5587.png
#  extracting: Images/5588.png
#  extracting: Images/5589.png
#  extracting: Images/559.png
#  extracting: Images/5590.png
#  extracting: Images/5591.png
#  extracting: Images/5592.png
#  extracting: Images/5593.png
#  extracting: Images/5594.png
#  extracting: Images/5595.png
#  extracting: Images/5596.png
#  extracting: Images/5597.png
#  extracting: Images/5598.png
#  extracting: Images/5599.png
#  extracting: Images/56.png
#  extracting: Images/560.png
#  extracting: Images/5600.png
#   inflating: Images/5601.png
#  extracting: Images/5602.png
#  extracting: Images/5603.png
#  extracting: Images/5604.png
#  extracting: Images/5605.png
#   inflating: Images/5606.png
#   inflating: Images/5607.png
#  extracting: Images/5608.png
#  extracting: Images/5609.png
#   inflating: Images/561.png
#  extracting: Images/5610.png
#  extracting: Images/5611.png
#  extracting: Images/5612.png
#  extracting: Images/5613.png
#  extracting: Images/5614.png
#  extracting: Images/5615.png
#  extracting: Images/5616.png
#  extracting: Images/5617.png
#  extracting: Images/5618.png
#  extracting: Images/5619.png
#  extracting: Images/562.png
#  extracting: Images/5620.png
#   inflating: Images/5621.png
#  extracting: Images/5622.png
#  extracting: Images/5623.png
#  extracting: Images/5624.png
#  extracting: Images/5625.png
#   inflating: Images/5626.png
#   inflating: Images/5627.png
#  extracting: Images/5628.png
#  extracting: Images/5629.png
#   inflating: Images/563.png
#  extracting: Images/5630.png
#  extracting: Images/5631.png
#  extracting: Images/5632.png
#  extracting: Images/5633.png
#   inflating: Images/5634.png
#   inflating: Images/5635.png
#  extracting: Images/5636.png
#  extracting: Images/5637.png
#  extracting: Images/5638.png
#  extracting: Images/5639.png
#   inflating: Images/564.png
#   inflating: Images/5640.png
#   inflating: Images/5641.png
#   inflating: Images/5642.png
#   inflating: Images/5643.png
#  extracting: Images/5644.png
#  extracting: Images/5645.png
#  extracting: Images/5646.png
#  extracting: Images/5647.png
#  extracting: Images/5648.png
#  extracting: Images/5649.png
#   inflating: Images/565.png
#  extracting: Images/5650.png
#  extracting: Images/5651.png
#  extracting: Images/5652.png
#  extracting: Images/5653.png
#  extracting: Images/5654.png
#  extracting: Images/5655.png
#  extracting: Images/5656.png
#  extracting: Images/5657.png
#  extracting: Images/5658.png
#  extracting: Images/5659.png
#   inflating: Images/566.png
#   inflating: Images/5660.png
#  extracting: Images/5661.png
#   inflating: Images/5662.png
#  extracting: Images/5663.png
#  extracting: Images/5664.png
#  extracting: Images/5665.png
#  extracting: Images/5666.png
#  extracting: Images/5667.png
#  extracting: Images/5668.png
#  extracting: Images/5669.png
#   inflating: Images/567.png
#  extracting: Images/5670.png
#  extracting: Images/5671.png
#  extracting: Images/5672.png
#  extracting: Images/5673.png
#  extracting: Images/5674.png
#  extracting: Images/5675.png
#  extracting: Images/5676.png
#  extracting: Images/5677.png
#  extracting: Images/5678.png
#  extracting: Images/5679.png
#  extracting: Images/568.png
#   inflating: Images/5680.png
#  extracting: Images/5681.png
#  extracting: Images/5682.png
#  extracting: Images/5683.png
#  extracting: Images/5684.png
#  extracting: Images/5685.png
#  extracting: Images/5686.png
#  extracting: Images/5687.png
#  extracting: Images/5688.png
#  extracting: Images/5689.png
#  extracting: Images/569.png
#  extracting: Images/5690.png
#   inflating: Images/5691.png
#  extracting: Images/5692.png
#   inflating: Images/5693.png
#   inflating: Images/5694.png
#  extracting: Images/5695.png
#  extracting: Images/5696.png
#  extracting: Images/5697.png
#  extracting: Images/5698.png
#  extracting: Images/5699.png
#  extracting: Images/57.png
#  extracting: Images/570.png
#  extracting: Images/5700.png
#   inflating: Images/5701.png
#  extracting: Images/5702.png
#  extracting: Images/5703.png
#  extracting: Images/5704.png
#  extracting: Images/5705.png
#   inflating: Images/5706.png
#   inflating: Images/5707.png
#  extracting: Images/5708.png
#  extracting: Images/5709.png
#  extracting: Images/571.png
#  extracting: Images/5710.png
#  extracting: Images/5711.png
#  extracting: Images/5712.png
#  extracting: Images/5713.png
#  extracting: Images/5714.png
#  extracting: Images/5715.png
#   inflating: Images/5716.png
#  extracting: Images/5717.png
#  extracting: Images/5718.png
#  extracting: Images/5719.png
#  extracting: Images/572.png
#  extracting: Images/5720.png
#  extracting: Images/5721.png
#  extracting: Images/5722.png
#  extracting: Images/5723.png
#  extracting: Images/5724.png
#  extracting: Images/5725.png
#  extracting: Images/5726.png
#  extracting: Images/5727.png
#  extracting: Images/5728.png
#  extracting: Images/5729.png
#  extracting: Images/573.png
#  extracting: Images/5730.png
#  extracting: Images/5731.png
#  extracting: Images/5732.png
#  extracting: Images/5733.png
#  extracting: Images/5734.png
#  extracting: Images/5735.png
#  extracting: Images/5736.png
#  extracting: Images/5737.png
#  extracting: Images/5738.png
#  extracting: Images/5739.png
#  extracting: Images/574.png
#  extracting: Images/5740.png
#  extracting: Images/5741.png
#  extracting: Images/5742.png
#  extracting: Images/5743.png
#  extracting: Images/5744.png
#  extracting: Images/5745.png
#  extracting: Images/5746.png
#  extracting: Images/5747.png
#  extracting: Images/5748.png
#   inflating: Images/5749.png
#  extracting: Images/575.png
#  extracting: Images/5750.png
#  extracting: Images/5751.png
#  extracting: Images/5752.png
#  extracting: Images/5753.png
#  extracting: Images/5754.png
#  extracting: Images/5755.png
#  extracting: Images/5756.png
#  extracting: Images/5757.png
#  extracting: Images/5758.png
#   inflating: Images/5759.png
#  extracting: Images/576.png
#   inflating: Images/5760.png
#  extracting: Images/5761.png
#   inflating: Images/5762.png
#  extracting: Images/5763.png
#  extracting: Images/5764.png
#  extracting: Images/5765.png
#  extracting: Images/5766.png
#   inflating: Images/5767.png
#  extracting: Images/5768.png
#  extracting: Images/5769.png
#  extracting: Images/577.png
#   inflating: Images/5770.png
#  extracting: Images/5771.png
#  extracting: Images/5772.png
#  extracting: Images/5773.png
#  extracting: Images/5774.png
#  extracting: Images/5775.png
#  extracting: Images/5776.png
#  extracting: Images/5777.png
#  extracting: Images/5778.png
#  extracting: Images/5779.png
#   inflating: Images/578.png
#  extracting: Images/5780.png
#   inflating: Images/5781.png
#  extracting: Images/5782.png
#  extracting: Images/5783.png
#  extracting: Images/5784.png
#  extracting: Images/5785.png
#  extracting: Images/5786.png
#   inflating: Images/5787.png
#   inflating: Images/5788.png
#  extracting: Images/5789.png
#  extracting: Images/579.png
#  extracting: Images/5790.png
#  extracting: Images/5791.png
#  extracting: Images/5792.png
#  extracting: Images/5793.png
#   inflating: Images/5794.png
#  extracting: Images/5795.png
#  extracting: Images/5796.png
#  extracting: Images/5797.png
#  extracting: Images/5798.png
#   inflating: Images/5799.png
#  extracting: Images/58.png
#   inflating: Images/580.png
#  extracting: Images/5800.png
#  extracting: Images/5801.png
#  extracting: Images/5802.png
#  extracting: Images/5803.png
#  extracting: Images/5804.png
#  extracting: Images/5805.png
#  extracting: Images/5806.png
#   inflating: Images/5807.png
#  extracting: Images/5808.png
#   inflating: Images/5809.png
#  extracting: Images/581.png
#  extracting: Images/5810.png
#  extracting: Images/5811.png
#  extracting: Images/5812.png
#  extracting: Images/5813.png
#   inflating: Images/5814.png
#   inflating: Images/5815.png
#  extracting: Images/5816.png
#  extracting: Images/5817.png
#  extracting: Images/5818.png
#  extracting: Images/5819.png
#  extracting: Images/582.png
#   inflating: Images/5820.png
#  extracting: Images/5821.png
#   inflating: Images/5822.png
#  extracting: Images/5823.png
#  extracting: Images/5824.png
#  extracting: Images/5825.png
#   inflating: Images/5826.png
#  extracting: Images/5827.png
#  extracting: Images/5828.png
#  extracting: Images/5829.png
#  extracting: Images/583.png
#  extracting: Images/5830.png
#  extracting: Images/5831.png
#  extracting: Images/5832.png
#   inflating: Images/5833.png
#  extracting: Images/5834.png
#   inflating: Images/5835.png
#  extracting: Images/5836.png
#  extracting: Images/5837.png
#  extracting: Images/5838.png
#  extracting: Images/5839.png
#  extracting: Images/584.png
#  extracting: Images/5840.png
#  extracting: Images/5841.png
#  extracting: Images/5842.png
#  extracting: Images/5843.png
#   inflating: Images/5844.png
#   inflating: Images/5845.png
#  extracting: Images/5846.png
#  extracting: Images/5847.png
#  extracting: Images/5848.png
#  extracting: Images/5849.png
#   inflating: Images/585.png
#   inflating: Images/5850.png
#  extracting: Images/5851.png
#   inflating: Images/5852.png
#  extracting: Images/5853.png
#  extracting: Images/5854.png
#  extracting: Images/5855.png
#  extracting: Images/5856.png
#   inflating: Images/5857.png
#  extracting: Images/5858.png
#  extracting: Images/5859.png
#  extracting: Images/586.png
#  extracting: Images/5860.png
#  extracting: Images/5861.png
#  extracting: Images/5862.png
#  extracting: Images/5863.png
#  extracting: Images/5864.png
#  extracting: Images/5865.png
#  extracting: Images/5866.png
#   inflating: Images/5867.png
#  extracting: Images/5868.png
#  extracting: Images/5869.png
#  extracting: Images/587.png
#  extracting: Images/5870.png
#  extracting: Images/5871.png
#  extracting: Images/5872.png
#  extracting: Images/5873.png
#  extracting: Images/5874.png
#  extracting: Images/5875.png
#  extracting: Images/5876.png
#  extracting: Images/5877.png
#  extracting: Images/5878.png
#   inflating: Images/5879.png
#  extracting: Images/588.png
#   inflating: Images/5880.png
#  extracting: Images/5881.png
#  extracting: Images/5882.png
#  extracting: Images/5883.png
#   inflating: Images/5884.png
#  extracting: Images/5885.png
#  extracting: Images/5886.png
#  extracting: Images/5887.png
#   inflating: Images/5888.png
#  extracting: Images/5889.png
#  extracting: Images/589.png
#  extracting: Images/5890.png
#  extracting: Images/5891.png
#  extracting: Images/5892.png
#  extracting: Images/5893.png
#  extracting: Images/5894.png
#   inflating: Images/5895.png
#  extracting: Images/5896.png
#  extracting: Images/5897.png
#  extracting: Images/5898.png
#  extracting: Images/5899.png
#  extracting: Images/59.png
#  extracting: Images/590.png
#  extracting: Images/5900.png
#  extracting: Images/5901.png
#   inflating: Images/5902.png
#  extracting: Images/5903.png
#  extracting: Images/5904.png
#   inflating: Images/5905.png
#  extracting: Images/5906.png
#  extracting: Images/5907.png
#   inflating: Images/5908.png
#  extracting: Images/5909.png
#  extracting: Images/591.png
#  extracting: Images/5910.png
#   inflating: Images/5911.png
#  extracting: Images/5912.png
#  extracting: Images/5913.png
#  extracting: Images/5914.png
#  extracting: Images/5915.png
#  extracting: Images/5916.png
#  extracting: Images/5917.png
#  extracting: Images/5918.png
#  extracting: Images/5919.png
#   inflating: Images/592.png
#   inflating: Images/5920.png
#   inflating: Images/5921.png
#   inflating: Images/5922.png
#  extracting: Images/5923.png
#  extracting: Images/5924.png
#  extracting: Images/5925.png
#  extracting: Images/5926.png
#  extracting: Images/5927.png
#  extracting: Images/5928.png
#  extracting: Images/5929.png
#   inflating: Images/593.png
#  extracting: Images/5930.png
#  extracting: Images/5931.png
#   inflating: Images/5932.png
#  extracting: Images/5933.png
#  extracting: Images/5934.png
#  extracting: Images/5935.png
#  extracting: Images/5936.png
#   inflating: Images/5937.png
#  extracting: Images/5938.png
#  extracting: Images/5939.png
#  extracting: Images/594.png
#   inflating: Images/5940.png
#  extracting: Images/5941.png
#  extracting: Images/5942.png
#  extracting: Images/5943.png
#  extracting: Images/5944.png
#  extracting: Images/5945.png
#  extracting: Images/5946.png
#   inflating: Images/5947.png
#  extracting: Images/5948.png
#   inflating: Images/5949.png
#   inflating: Images/595.png
#  extracting: Images/5950.png
#  extracting: Images/5951.png
#   inflating: Images/5952.png
#  extracting: Images/5953.png
#  extracting: Images/5954.png
#  extracting: Images/5955.png
#  extracting: Images/5956.png
#  extracting: Images/5957.png
#  extracting: Images/5958.png
#   inflating: Images/5959.png
#  extracting: Images/596.png
#  extracting: Images/5960.png
#  extracting: Images/5961.png
#  extracting: Images/5962.png
#  extracting: Images/5963.png
#  extracting: Images/5964.png
#  extracting: Images/5965.png
#  extracting: Images/5966.png
#  extracting: Images/5967.png
#  extracting: Images/5968.png
#  extracting: Images/5969.png
#  extracting: Images/597.png
#  extracting: Images/5970.png
#  extracting: Images/5971.png
#  extracting: Images/5972.png
#  extracting: Images/5973.png
#   inflating: Images/5974.png
#   inflating: Images/5975.png
#  extracting: Images/5976.png
#  extracting: Images/5977.png
#  extracting: Images/5978.png
#  extracting: Images/5979.png
#   inflating: Images/598.png
#  extracting: Images/5980.png
#  extracting: Images/5981.png
#  extracting: Images/5982.png
#  extracting: Images/5983.png
#  extracting: Images/5984.png
#  extracting: Images/5985.png
#  extracting: Images/5986.png
#  extracting: Images/5987.png
#   inflating: Images/5988.png
#  extracting: Images/5989.png
#  extracting: Images/599.png
#  extracting: Images/5990.png
#   inflating: Images/5991.png
#  extracting: Images/5992.png
#  extracting: Images/5993.png
#  extracting: Images/5994.png
#  extracting: Images/5995.png
#  extracting: Images/5996.png
#  extracting: Images/5997.png
#  extracting: Images/5998.png
#  extracting: Images/5999.png
#  extracting: Images/6.png
#  extracting: Images/60.png
#  extracting: Images/600.png
#  extracting: Images/6000.png
#  extracting: Images/6001.png
#   inflating: Images/6002.png
#  extracting: Images/6003.png
#  extracting: Images/6004.png
#   inflating: Images/6005.png
#  extracting: Images/6006.png
#  extracting: Images/6007.png
#  extracting: Images/6008.png
#   inflating: Images/6009.png
#  extracting: Images/601.png
#  extracting: Images/6010.png
#  extracting: Images/6011.png
#  extracting: Images/6012.png
#  extracting: Images/6013.png
#  extracting: Images/6014.png
#  extracting: Images/6015.png
#  extracting: Images/6016.png
#  extracting: Images/6017.png
#  extracting: Images/6018.png
#  extracting: Images/6019.png
#  extracting: Images/602.png
#  extracting: Images/6020.png
#  extracting: Images/6021.png
#  extracting: Images/6022.png
#  extracting: Images/6023.png
#  extracting: Images/6024.png
#  extracting: Images/6025.png
#  extracting: Images/6026.png
#   inflating: Images/6027.png
#  extracting: Images/6028.png
#  extracting: Images/6029.png
#  extracting: Images/603.png
#   inflating: Images/6030.png
#  extracting: Images/6031.png
#  extracting: Images/6032.png
#  extracting: Images/6033.png
#  extracting: Images/6034.png
#  extracting: Images/6035.png
#  extracting: Images/6036.png
#   inflating: Images/6037.png
#  extracting: Images/6038.png
#  extracting: Images/6039.png
#  extracting: Images/604.png
#  extracting: Images/6040.png
#  extracting: Images/6041.png
#  extracting: Images/6042.png
#  extracting: Images/6043.png
#  extracting: Images/6044.png
#  extracting: Images/6045.png
#  extracting: Images/6046.png
#  extracting: Images/6047.png
#  extracting: Images/6048.png
#  extracting: Images/6049.png
#  extracting: Images/605.png
#  extracting: Images/6050.png
#  extracting: Images/6051.png
#  extracting: Images/6052.png
#  extracting: Images/6053.png
#  extracting: Images/6054.png
#  extracting: Images/6055.png
#  extracting: Images/6056.png
#  extracting: Images/6057.png
#  extracting: Images/6058.png
#  extracting: Images/6059.png
#  extracting: Images/606.png
#  extracting: Images/6060.png
#  extracting: Images/6061.png
#  extracting: Images/6062.png
#   inflating: Images/6063.png
#  extracting: Images/6064.png
#  extracting: Images/6065.png
#  extracting: Images/6066.png
#  extracting: Images/6067.png
#  extracting: Images/6068.png
#  extracting: Images/6069.png
#  extracting: Images/607.png
#  extracting: Images/6070.png
#  extracting: Images/6071.png
#  extracting: Images/6072.png
#  extracting: Images/6073.png
#  extracting: Images/6074.png
#  extracting: Images/6075.png
#   inflating: Images/6076.png
#  extracting: Images/6077.png
#  extracting: Images/6078.png
#  extracting: Images/6079.png
#  extracting: Images/608.png
#  extracting: Images/6080.png
#   inflating: Images/6081.png
#  extracting: Images/6082.png
#  extracting: Images/6083.png
#  extracting: Images/6084.png
#  extracting: Images/6085.png
#  extracting: Images/6086.png
#  extracting: Images/6087.png
#  extracting: Images/6088.png
#  extracting: Images/6089.png
#  extracting: Images/609.png
#   inflating: Images/6090.png
#  extracting: Images/6091.png
#  extracting: Images/6092.png
#  extracting: Images/6093.png
#  extracting: Images/6094.png
#  extracting: Images/6095.png
#  extracting: Images/6096.png
#  extracting: Images/6097.png
#  extracting: Images/6098.png
#  extracting: Images/6099.png
#  extracting: Images/61.png
#  extracting: Images/610.png
#  extracting: Images/6100.png
#  extracting: Images/6101.png
#  extracting: Images/6102.png
#   inflating: Images/6103.png
#  extracting: Images/6104.png
#  extracting: Images/6105.png
#  extracting: Images/6106.png
#  extracting: Images/6107.png
#  extracting: Images/6108.png
#   inflating: Images/6109.png
#  extracting: Images/611.png
#  extracting: Images/6110.png
#  extracting: Images/6111.png
#  extracting: Images/6112.png
#   inflating: Images/6113.png
#  extracting: Images/6114.png
#  extracting: Images/6115.png
#  extracting: Images/6116.png
#  extracting: Images/6117.png
#  extracting: Images/6118.png
#  extracting: Images/6119.png
#  extracting: Images/612.png
#  extracting: Images/6120.png
#   inflating: Images/6121.png
#  extracting: Images/6122.png
#  extracting: Images/6123.png
#   inflating: Images/6124.png
#  extracting: Images/6125.png
#  extracting: Images/6126.png
#  extracting: Images/6127.png
#  extracting: Images/6128.png
#  extracting: Images/6129.png
#   inflating: Images/613.png
#  extracting: Images/6130.png
#   inflating: Images/6131.png
#  extracting: Images/6132.png
#  extracting: Images/6133.png
#  extracting: Images/6134.png
#  extracting: Images/6135.png
#  extracting: Images/6136.png
#   inflating: Images/6137.png
#   inflating: Images/6138.png
#  extracting: Images/6139.png
#  extracting: Images/614.png
#  extracting: Images/6140.png
#  extracting: Images/6141.png
#   inflating: Images/6142.png
#  extracting: Images/6143.png
#  extracting: Images/6144.png
#   inflating: Images/6145.png
#  extracting: Images/6146.png
#   inflating: Images/6147.png
#  extracting: Images/6148.png
#  extracting: Images/6149.png
#  extracting: Images/615.png
#   inflating: Images/6150.png
#  extracting: Images/6151.png
#  extracting: Images/6152.png
#  extracting: Images/6153.png
#   inflating: Images/6154.png
#  extracting: Images/6155.png
#  extracting: Images/6156.png
#  extracting: Images/6157.png
#   inflating: Images/6158.png
#   inflating: Images/6159.png
#  extracting: Images/616.png
#  extracting: Images/6160.png
#  extracting: Images/6161.png
#  extracting: Images/6162.png
#  extracting: Images/6163.png
#  extracting: Images/6164.png
#  extracting: Images/6165.png
#   inflating: Images/6166.png
#  extracting: Images/6167.png
#  extracting: Images/6168.png
#  extracting: Images/6169.png
#  extracting: Images/617.png
#  extracting: Images/6170.png
#   inflating: Images/6171.png
#  extracting: Images/6172.png
#  extracting: Images/6173.png
#  extracting: Images/6174.png
#   inflating: Images/6175.png
#  extracting: Images/6176.png
#  extracting: Images/6177.png
#   inflating: Images/6178.png
#  extracting: Images/6179.png
#  extracting: Images/618.png
#  extracting: Images/6180.png
#   inflating: Images/6181.png
#   inflating: Images/6182.png
#  extracting: Images/6183.png
#  extracting: Images/6184.png
#   inflating: Images/6185.png
#  extracting: Images/6186.png
#  extracting: Images/6187.png
#   inflating: Images/6188.png
#  extracting: Images/6189.png
#  extracting: Images/619.png
#   inflating: Images/6190.png
#  extracting: Images/6191.png
#  extracting: Images/6192.png
#  extracting: Images/6193.png
#  extracting: Images/6194.png
#  extracting: Images/6195.png
#  extracting: Images/6196.png
#  extracting: Images/6197.png
#  extracting: Images/6198.png
#  extracting: Images/6199.png
#  extracting: Images/62.png
#  extracting: Images/620.png
#   inflating: Images/6200.png
#  extracting: Images/6201.png
#  extracting: Images/6202.png
#  extracting: Images/6203.png
#  extracting: Images/6204.png
#  extracting: Images/6205.png
#  extracting: Images/6206.png
#  extracting: Images/6207.png
#  extracting: Images/6208.png
#  extracting: Images/6209.png
#  extracting: Images/621.png
#  extracting: Images/6210.png
#  extracting: Images/6211.png
#  extracting: Images/6212.png
#  extracting: Images/6213.png
#   inflating: Images/6214.png
#   inflating: Images/6215.png
#  extracting: Images/6216.png
#  extracting: Images/6217.png
#  extracting: Images/6218.png
#  extracting: Images/6219.png
#  extracting: Images/622.png
#  extracting: Images/6220.png
#  extracting: Images/6221.png
#  extracting: Images/6222.png
#  extracting: Images/6223.png
#  extracting: Images/6224.png
#  extracting: Images/6225.png
#  extracting: Images/6226.png
#  extracting: Images/6227.png
#  extracting: Images/6228.png
#  extracting: Images/6229.png
#  extracting: Images/623.png
#  extracting: Images/6230.png
#  extracting: Images/6231.png
#  extracting: Images/6232.png
#   inflating: Images/6233.png
#  extracting: Images/6234.png
#  extracting: Images/6235.png
#  extracting: Images/6236.png
#  extracting: Images/6237.png
#  extracting: Images/6238.png
#  extracting: Images/6239.png
#  extracting: Images/624.png
#  extracting: Images/6240.png
#  extracting: Images/6241.png
#  extracting: Images/6242.png
#  extracting: Images/6243.png
#  extracting: Images/6244.png
#  extracting: Images/6245.png
#   inflating: Images/6246.png
#   inflating: Images/6247.png
#  extracting: Images/6248.png
#  extracting: Images/6249.png
#  extracting: Images/625.png
#  extracting: Images/6250.png
#  extracting: Images/6251.png
#  extracting: Images/6252.png
#  extracting: Images/6253.png
#  extracting: Images/6254.png
#  extracting: Images/6255.png
#  extracting: Images/6256.png
#  extracting: Images/6257.png
#  extracting: Images/6258.png
#  extracting: Images/6259.png
#  extracting: Images/626.png
#  extracting: Images/6260.png
#  extracting: Images/6261.png
#  extracting: Images/6262.png
#  extracting: Images/6263.png
#   inflating: Images/6264.png
#  extracting: Images/6265.png
#  extracting: Images/6266.png
#  extracting: Images/6267.png
#  extracting: Images/6268.png
#  extracting: Images/6269.png
#  extracting: Images/627.png
#  extracting: Images/6270.png
#   inflating: Images/6271.png
#   inflating: Images/6272.png
#   inflating: Images/6273.png
#   inflating: Images/6274.png
#  extracting: Images/6275.png
#   inflating: Images/6276.png
#  extracting: Images/6277.png
#  extracting: Images/6278.png
#  extracting: Images/6279.png
#  extracting: Images/628.png
#   inflating: Images/6280.png
#   inflating: Images/6281.png
#  extracting: Images/6282.png
#   inflating: Images/6283.png
#  extracting: Images/6284.png
#  extracting: Images/6285.png
#  extracting: Images/6286.png
#  extracting: Images/6287.png
#  extracting: Images/6288.png
#  extracting: Images/6289.png
#  extracting: Images/629.png
#   inflating: Images/6290.png
#  extracting: Images/6291.png
#  extracting: Images/6292.png
#   inflating: Images/6293.png
#  extracting: Images/6294.png
#  extracting: Images/6295.png
#   inflating: Images/6296.png
#  extracting: Images/6297.png
#   inflating: Images/6298.png
#  extracting: Images/6299.png
#   inflating: Images/63.png
#  extracting: Images/630.png
#  extracting: Images/6300.png
#  extracting: Images/6301.png
#  extracting: Images/6302.png
#  extracting: Images/6303.png
#  extracting: Images/6304.png
#  extracting: Images/6305.png
#  extracting: Images/6306.png
#   inflating: Images/6307.png
#  extracting: Images/6308.png
#  extracting: Images/6309.png
#  extracting: Images/631.png
#  extracting: Images/6310.png
#  extracting: Images/6311.png
#  extracting: Images/6312.png
#   inflating: Images/6313.png
#  extracting: Images/6314.png
#  extracting: Images/6315.png
#  extracting: Images/6316.png
#   inflating: Images/6317.png
#  extracting: Images/6318.png
#  extracting: Images/6319.png
#  extracting: Images/632.png
#  extracting: Images/6320.png
#   inflating: Images/6321.png
#  extracting: Images/6322.png
#  extracting: Images/6323.png
#  extracting: Images/6324.png
#  extracting: Images/6325.png
#  extracting: Images/6326.png
#  extracting: Images/6327.png
#   inflating: Images/6328.png
#  extracting: Images/6329.png
#  extracting: Images/633.png
#  extracting: Images/6330.png
#  extracting: Images/6331.png
#  extracting: Images/6332.png
#  extracting: Images/6333.png
#  extracting: Images/6334.png
#   inflating: Images/6335.png
#   inflating: Images/6336.png
#  extracting: Images/6337.png
#   inflating: Images/6338.png
#  extracting: Images/6339.png
#  extracting: Images/634.png
#  extracting: Images/6340.png
#  extracting: Images/6341.png
#  extracting: Images/6342.png
#  extracting: Images/6343.png
#  extracting: Images/6344.png
#  extracting: Images/6345.png
#  extracting: Images/6346.png
#  extracting: Images/6347.png
#  extracting: Images/6348.png
#  extracting: Images/6349.png
#  extracting: Images/635.png
#  extracting: Images/6350.png
#  extracting: Images/6351.png
#  extracting: Images/6352.png
#  extracting: Images/6353.png
#   inflating: Images/6354.png
#  extracting: Images/6355.png
#   inflating: Images/6356.png
#  extracting: Images/6357.png
#   inflating: Images/6358.png
#  extracting: Images/6359.png
#   inflating: Images/636.png
#  extracting: Images/6360.png
#  extracting: Images/6361.png
#  extracting: Images/6362.png
#  extracting: Images/6363.png
#  extracting: Images/6364.png
#  extracting: Images/6365.png
#  extracting: Images/6366.png
#  extracting: Images/6367.png
#  extracting: Images/6368.png
#   inflating: Images/6369.png
#  extracting: Images/637.png
#  extracting: Images/6370.png
#  extracting: Images/6371.png
#  extracting: Images/6372.png
#   inflating: Images/6373.png
#  extracting: Images/6374.png
#  extracting: Images/6375.png
#  extracting: Images/6376.png
#  extracting: Images/6377.png
#  extracting: Images/6378.png
#  extracting: Images/6379.png
#  extracting: Images/638.png
#  extracting: Images/6380.png
#   inflating: Images/6381.png
#  extracting: Images/6382.png
#  extracting: Images/6383.png
#  extracting: Images/6384.png
#  extracting: Images/6385.png
#  extracting: Images/6386.png
#  extracting: Images/6387.png
#  extracting: Images/6388.png
#  extracting: Images/6389.png
#   inflating: Images/639.png
#   inflating: Images/6390.png
#  extracting: Images/6391.png
#  extracting: Images/6392.png
#  extracting: Images/6393.png
#  extracting: Images/6394.png
#  extracting: Images/6395.png
#  extracting: Images/6396.png
#  extracting: Images/6397.png
#  extracting: Images/6398.png
#  extracting: Images/6399.png
#  extracting: Images/64.png
#  extracting: Images/640.png
#   inflating: Images/6400.png
#  extracting: Images/6401.png
#  extracting: Images/6402.png
#  extracting: Images/6403.png
#  extracting: Images/6404.png
#  extracting: Images/6405.png
#   inflating: Images/6406.png
#  extracting: Images/6407.png
#   inflating: Images/6408.png
#  extracting: Images/6409.png
#  extracting: Images/641.png
#  extracting: Images/6410.png
#  extracting: Images/6411.png
#  extracting: Images/6412.png
#  extracting: Images/6413.png
#   inflating: Images/6414.png
#  extracting: Images/6415.png
#  extracting: Images/6416.png
#  extracting: Images/6417.png
#  extracting: Images/6418.png
#  extracting: Images/6419.png
#  extracting: Images/642.png
#  extracting: Images/6420.png
#  extracting: Images/6421.png
#  extracting: Images/6422.png
#   inflating: Images/6423.png
#   inflating: Images/6424.png
#  extracting: Images/6425.png
#   inflating: Images/6426.png
#  extracting: Images/6427.png
#  extracting: Images/6428.png
#  extracting: Images/6429.png
#  extracting: Images/643.png
#  extracting: Images/6430.png
#  extracting: Images/6431.png
#  extracting: Images/6432.png
#  extracting: Images/6433.png
#  extracting: Images/6434.png
#   inflating: Images/6435.png
#  extracting: Images/6436.png
#   inflating: Images/6437.png
#  extracting: Images/6438.png
#  extracting: Images/6439.png
#  extracting: Images/644.png
#  extracting: Images/6440.png
#  extracting: Images/6441.png
#  extracting: Images/6442.png
#  extracting: Images/6443.png
#  extracting: Images/6444.png
#  extracting: Images/6445.png
#  extracting: Images/6446.png
#  extracting: Images/6447.png
#  extracting: Images/6448.png
#  extracting: Images/6449.png
#  extracting: Images/645.png
#  extracting: Images/6450.png
#  extracting: Images/6451.png
#   inflating: Images/6452.png
#  extracting: Images/6453.png
#  extracting: Images/6454.png
#  extracting: Images/6455.png
#  extracting: Images/6456.png
#  extracting: Images/6457.png
#  extracting: Images/6458.png
#  extracting: Images/6459.png
#   inflating: Images/646.png
#  extracting: Images/6460.png
#  extracting: Images/6461.png
#  extracting: Images/6462.png
#  extracting: Images/6463.png
#   inflating: Images/6464.png
#  extracting: Images/6465.png
#  extracting: Images/6466.png
#  extracting: Images/6467.png
#  extracting: Images/6468.png
#  extracting: Images/6469.png
#  extracting: Images/647.png
#  extracting: Images/6470.png
#  extracting: Images/6471.png
#  extracting: Images/6472.png
#  extracting: Images/6473.png
#  extracting: Images/6474.png
#  extracting: Images/6475.png
#  extracting: Images/6476.png
#   inflating: Images/6477.png
#  extracting: Images/6478.png
#  extracting: Images/6479.png
#  extracting: Images/648.png
#  extracting: Images/6480.png
#  extracting: Images/6481.png
#   inflating: Images/6482.png
#  extracting: Images/6483.png
#   inflating: Images/6484.png
#   inflating: Images/6485.png
#  extracting: Images/6486.png
#  extracting: Images/6487.png
#   inflating: Images/6488.png
#  extracting: Images/6489.png
#  extracting: Images/649.png
#   inflating: Images/6490.png
#   inflating: Images/6491.png
#  extracting: Images/6492.png
#  extracting: Images/6493.png
#  extracting: Images/6494.png
#  extracting: Images/6495.png
#   inflating: Images/6496.png
#  extracting: Images/6497.png
#   inflating: Images/6498.png
#  extracting: Images/6499.png
#  extracting: Images/65.png
#  extracting: Images/650.png
#  extracting: Images/6500.png
#  extracting: Images/6501.png
#   inflating: Images/6502.png
#  extracting: Images/6503.png
#  extracting: Images/6504.png
#  extracting: Images/6505.png
#  extracting: Images/6506.png
#   inflating: Images/6507.png
#  extracting: Images/6508.png
#  extracting: Images/6509.png
#  extracting: Images/651.png
#  extracting: Images/6510.png
#  extracting: Images/6511.png
#  extracting: Images/6512.png
#  extracting: Images/6513.png
#  extracting: Images/6514.png
#  extracting: Images/6515.png
#  extracting: Images/6516.png
#  extracting: Images/6517.png
#   inflating: Images/6518.png
#  extracting: Images/6519.png
#  extracting: Images/652.png
#   inflating: Images/6520.png
#  extracting: Images/6521.png
#  extracting: Images/6522.png
#  extracting: Images/6523.png
#  extracting: Images/6524.png
#  extracting: Images/6525.png
#  extracting: Images/6526.png
#  extracting: Images/6527.png
#   inflating: Images/6528.png
#  extracting: Images/6529.png
#  extracting: Images/653.png
#  extracting: Images/6530.png
#  extracting: Images/6531.png
#  extracting: Images/6532.png
#  extracting: Images/6533.png
#  extracting: Images/6534.png
#   inflating: Images/6535.png
#  extracting: Images/6536.png
#  extracting: Images/6537.png
#  extracting: Images/6538.png
#   inflating: Images/6539.png
#  extracting: Images/654.png
#  extracting: Images/6540.png
#  extracting: Images/6541.png
#   inflating: Images/6542.png
#   inflating: Images/6543.png
#  extracting: Images/6544.png
#  extracting: Images/6545.png
#  extracting: Images/6546.png
#  extracting: Images/6547.png
#  extracting: Images/6548.png
#  extracting: Images/6549.png
#  extracting: Images/655.png
#  extracting: Images/6550.png
#  extracting: Images/6551.png
#  extracting: Images/6552.png
#  extracting: Images/6553.png
#   inflating: Images/6554.png
#  extracting: Images/6555.png
#  extracting: Images/6556.png
#  extracting: Images/6557.png
#   inflating: Images/6558.png
#  extracting: Images/6559.png
#   inflating: Images/656.png
#  extracting: Images/6560.png
#  extracting: Images/6561.png
#   inflating: Images/6562.png
#  extracting: Images/6563.png
#  extracting: Images/6564.png
#  extracting: Images/6565.png
#  extracting: Images/6566.png
#  extracting: Images/6567.png
#   inflating: Images/6568.png
#  extracting: Images/6569.png
#  extracting: Images/657.png
#  extracting: Images/6570.png
#  extracting: Images/6571.png
#  extracting: Images/6572.png
#  extracting: Images/6573.png
#  extracting: Images/6574.png
#   inflating: Images/6575.png
#  extracting: Images/6576.png
#  extracting: Images/6577.png
#  extracting: Images/6578.png
#   inflating: Images/6579.png
#  extracting: Images/658.png
#  extracting: Images/6580.png
#  extracting: Images/6581.png
#  extracting: Images/6582.png
#  extracting: Images/6583.png
#  extracting: Images/6584.png
#  extracting: Images/6585.png
#  extracting: Images/6586.png
#  extracting: Images/6587.png
#  extracting: Images/6588.png
#  extracting: Images/6589.png
#  extracting: Images/659.png
#   inflating: Images/6590.png
#   inflating: Images/6591.png
#  extracting: Images/6592.png
#  extracting: Images/6593.png
#  extracting: Images/6594.png
#  extracting: Images/6595.png
#  extracting: Images/6596.png
#  extracting: Images/6597.png
#  extracting: Images/6598.png
#   inflating: Images/6599.png
#  extracting: Images/66.png
#   inflating: Images/660.png
#  extracting: Images/6600.png
#  extracting: Images/6601.png
#  extracting: Images/6602.png
#  extracting: Images/6603.png
#  extracting: Images/6604.png
#  extracting: Images/6605.png
#   inflating: Images/6606.png
#  extracting: Images/6607.png
#  extracting: Images/6608.png
#  extracting: Images/6609.png
#  extracting: Images/661.png
#  extracting: Images/6610.png
#  extracting: Images/6611.png
#  extracting: Images/6612.png
#   inflating: Images/6613.png
#  extracting: Images/6614.png
#  extracting: Images/6615.png
#  extracting: Images/6616.png
#  extracting: Images/6617.png
#  extracting: Images/6618.png
#  extracting: Images/6619.png
#  extracting: Images/662.png
#   inflating: Images/6620.png
#  extracting: Images/6621.png
#   inflating: Images/6622.png
#  extracting: Images/6623.png
#   inflating: Images/6624.png
#  extracting: Images/6625.png
#  extracting: Images/6626.png
#   inflating: Images/6627.png
#  extracting: Images/6628.png
#  extracting: Images/6629.png
#  extracting: Images/663.png
#  extracting: Images/6630.png
#  extracting: Images/6631.png
#  extracting: Images/6632.png
#  extracting: Images/6633.png
#  extracting: Images/6634.png
# ...
#  extracting: Images/9620.png
#  extracting: Images/9621.png
#   inflating: Images/9622.png
#  extracting: Images/9623.png
#   inflating: Images/9624.png
#  extracting: Images/9625.png
#  extracting: Images/9626.png
#   inflating: Images/9627.png
#  extracting: Images/9628.png
#  extracting: Images/9629.png
#   inflating: Images/963.png
#  extracting: Images/9630.png
#  extracting: Images/9631.png
#  extracting: Images/9632.png
#  extracting: Images/9633.png
#   inflating: Images/9634.png
#  extracting: Images/9635.png
#  extracting: Images/9636.png
#  extracting: Images/9637.png
#  extracting: Images/9638.png
#   inflating: Images/9639.png
#  extracting: Images/964.png
#  extracting: Images/9640.png
#  extracting: Images/9641.png
#  extracting: Images/9642.png
#  extracting: Images/9643.png
#  extracting: Images/9644.png
#  extracting: Images/9645.png
#  extracting: Images/9646.png
#  extracting: Images/9647.png
#   inflating: Images/9648.png
#  extracting: Images/9649.png
#   inflating: Images/965.png
#  extracting: Images/9650.png
#  extracting: Images/9651.png
#  extracting: Images/9652.png
#  extracting: Images/9653.png
#  extracting: Images/9654.png
#  extracting: Images/9655.png
#  extracting: Images/9656.png
#  extracting: Images/9657.png
#  extracting: Images/9658.png
#   inflating: Images/9659.png
#  extracting: Images/966.png
#  extracting: Images/9660.png
#   inflating: Images/9661.png
#   inflating: Images/9662.png
#  extracting: Images/9663.png
#  extracting: Images/9664.png
#  extracting: Images/9665.png
#  extracting: Images/9666.png
#  extracting: Images/9667.png
#  extracting: Images/9668.png
#  extracting: Images/9669.png
#  extracting: Images/967.png
#  extracting: Images/9670.png
#  extracting: Images/9671.png
#  extracting: Images/9672.png
#  extracting: Images/9673.png
#  extracting: Images/9674.png
#  extracting: Images/9675.png
#  extracting: Images/9676.png
#  extracting: Images/9677.png
#  extracting: Images/9678.png
#  extracting: Images/9679.png
#  extracting: Images/968.png
#   inflating: Images/9680.png
#  extracting: Images/9681.png
#   inflating: Images/9682.png
#   inflating: Images/9683.png
#  extracting: Images/9684.png
#  extracting: Images/9685.png
#  extracting: Images/9686.png
#  extracting: Images/9687.png
#  extracting: Images/9688.png
#  extracting: Images/9689.png
#  extracting: Images/969.png
#  extracting: Images/9690.png
#  extracting: Images/9691.png
#   inflating: Images/9692.png
#  extracting: Images/9693.png
#  extracting: Images/9694.png
#  extracting: Images/9695.png
#  extracting: Images/9696.png
#  extracting: Images/9697.png
#  extracting: Images/9698.png
#  extracting: Images/9699.png
#  extracting: Images/97.png
#  extracting: Images/970.png
#  extracting: Images/9700.png
#  extracting: Images/9701.png
#  extracting: Images/9702.png
#  extracting: Images/9703.png
#   inflating: Images/9704.png
#   inflating: Images/9705.png
#  extracting: Images/9706.png
#   inflating: Images/9707.png
#  extracting: Images/9708.png
#  extracting: Images/9709.png
#  extracting: Images/971.png
#  extracting: Images/9710.png
#   inflating: Images/9711.png
#  extracting: Images/9712.png
#   inflating: Images/9713.png
#  extracting: Images/9714.png
#  extracting: Images/9715.png
#  extracting: Images/9716.png
#  extracting: Images/9717.png
#  extracting: Images/9718.png
#   inflating: Images/9719.png
#  extracting: Images/972.png
#  extracting: Images/9720.png
#  extracting: Images/9721.png
#  extracting: Images/9722.png
#  extracting: Images/9723.png
#   inflating: Images/9724.png
#  extracting: Images/9725.png
#  extracting: Images/9726.png
#  extracting: Images/9727.png
#  extracting: Images/9728.png
#  extracting: Images/9729.png
#  extracting: Images/973.png
#  extracting: Images/9730.png
#  extracting: Images/9731.png
#  extracting: Images/9732.png
#  extracting: Images/9733.png
#  extracting: Images/9734.png
#  extracting: Images/9735.png
#  extracting: Images/9736.png
#   inflating: Images/9737.png
#   inflating: Images/9738.png
#  extracting: Images/9739.png
#  extracting: Images/974.png
#  extracting: Images/9740.png
#  extracting: Images/9741.png
#  extracting: Images/9742.png
#  extracting: Images/9743.png
#  extracting: Images/9744.png
#  extracting: Images/9745.png
#  extracting: Images/9746.png
#  extracting: Images/9747.png
#  extracting: Images/9748.png
#  extracting: Images/9749.png
#  extracting: Images/975.png
#  extracting: Images/9750.png
#  extracting: Images/9751.png
#  extracting: Images/9752.png
#   inflating: Images/9753.png
#   inflating: Images/9754.png
#  extracting: Images/9755.png
#  extracting: Images/9756.png
#  extracting: Images/9757.png
#  extracting: Images/9758.png
#   inflating: Images/9759.png
#  extracting: Images/976.png
#   inflating: Images/9760.png
#  extracting: Images/9761.png
#  extracting: Images/9762.png
#  extracting: Images/9763.png
#  extracting: Images/9764.png
#  extracting: Images/9765.png
#  extracting: Images/9766.png
#  extracting: Images/9767.png
#   inflating: Images/9768.png
#  extracting: Images/9769.png
#  extracting: Images/977.png
#  extracting: Images/9770.png
#  extracting: Images/9771.png
#  extracting: Images/9772.png
#  extracting: Images/9773.png
#  extracting: Images/9774.png
#   inflating: Images/9775.png
#  extracting: Images/9776.png
#  extracting: Images/9777.png
#  extracting: Images/9778.png
#  extracting: Images/9779.png
#  extracting: Images/978.png
#   inflating: Images/9780.png
#  extracting: Images/9781.png
#  extracting: Images/9782.png
#  extracting: Images/9783.png
#  extracting: Images/9784.png
#  extracting: Images/9785.png
#  extracting: Images/9786.png
#  extracting: Images/9787.png
#   inflating: Images/9788.png
#  extracting: Images/9789.png
#  extracting: Images/979.png
#  extracting: Images/9790.png
#   inflating: Images/9791.png
#  extracting: Images/9792.png
#  extracting: Images/9793.png
#  extracting: Images/9794.png
#  extracting: Images/9795.png
#  extracting: Images/9796.png
#  extracting: Images/9797.png
#  extracting: Images/9798.png
#  extracting: Images/9799.png
#  extracting: Images/98.png
#  extracting: Images/980.png
#  extracting: Images/9800.png
#  extracting: Images/9801.png
#  extracting: Images/9802.png
#   inflating: Images/9803.png
#  extracting: Images/9804.png
#   inflating: Images/9805.png
#  extracting: Images/9806.png
#  extracting: Images/9807.png
#  extracting: Images/9808.png
#  extracting: Images/9809.png
#   inflating: Images/981.png
#  extracting: Images/9810.png
#  extracting: Images/9811.png
#  extracting: Images/9812.png
#  extracting: Images/9813.png
#  extracting: Images/9814.png
#  extracting: Images/9815.png
#  extracting: Images/9816.png
#  extracting: Images/9817.png
#  extracting: Images/9818.png
#  extracting: Images/9819.png
#  extracting: Images/982.png
#  extracting: Images/9820.png
#  extracting: Images/9821.png
#  extracting: Images/9822.png
#   inflating: Images/9823.png
#   inflating: Images/9824.png
#  extracting: Images/9825.png
#  extracting: Images/9826.png
#  extracting: Images/9827.png
#  extracting: Images/9828.png
#  extracting: Images/9829.png
#   inflating: Images/983.png
#  extracting: Images/9830.png
#   inflating: Images/9831.png
#  extracting: Images/9832.png
#  extracting: Images/9833.png
#  extracting: Images/9834.png
#  extracting: Images/9835.png
#   inflating: Images/9836.png
#  extracting: Images/9837.png
#  extracting: Images/9838.png
#  extracting: Images/9839.png
#   inflating: Images/984.png
#  extracting: Images/9840.png
#  extracting: Images/9841.png
#  extracting: Images/9842.png
#  extracting: Images/9843.png
#   inflating: Images/9844.png
#   inflating: Images/9845.png
#   inflating: Images/9846.png
#  extracting: Images/9847.png
#  extracting: Images/9848.png
#  extracting: Images/9849.png
#  extracting: Images/985.png
#  extracting: Images/9850.png
#  extracting: Images/9851.png
#  extracting: Images/9852.png
#  extracting: Images/9853.png
#  extracting: Images/9854.png
#  extracting: Images/9855.png
#  extracting: Images/9856.png
#   inflating: Images/9857.png
#  extracting: Images/9858.png
#  extracting: Images/9859.png
#  extracting: Images/986.png
#  extracting: Images/9860.png
#  extracting: Images/9861.png
#  extracting: Images/9862.png
#   inflating: Images/9863.png
#  extracting: Images/9864.png
#   inflating: Images/9865.png
#   inflating: Images/9866.png
#  extracting: Images/9867.png
#  extracting: Images/9868.png
#   inflating: Images/9869.png
#  extracting: Images/987.png
#  extracting: Images/9870.png
#  extracting: Images/9871.png
#  extracting: Images/9872.png
#  extracting: Images/9873.png
#   inflating: Images/9874.png
#  extracting: Images/9875.png
#  extracting: Images/9876.png
#  extracting: Images/9877.png
#  extracting: Images/9878.png
#  extracting: Images/9879.png
#  extracting: Images/988.png
#  extracting: Images/9880.png
#  extracting: Images/9881.png
#  extracting: Images/9882.png
#  extracting: Images/9883.png
#  extracting: Images/9884.png
#  extracting: Images/9885.png
#  extracting: Images/9886.png
#  extracting: Images/9887.png
#  extracting: Images/9888.png
#  extracting: Images/9889.png
#  extracting: Images/989.png
#  extracting: Images/9890.png
#  extracting: Images/9891.png
#  extracting: Images/9892.png
#   inflating: Images/9893.png
#   inflating: Images/9894.png
#  extracting: Images/9895.png
#  extracting: Images/9896.png
#  extracting: Images/9897.png
#  extracting: Images/9898.png
#   inflating: Images/9899.png
#  extracting: Images/99.png
#  extracting: Images/990.png
#   inflating: Images/9900.png
#  extracting: Images/9901.png
#  extracting: Images/9902.png
#   inflating: Images/9903.png
#  extracting: Images/9904.png
#   inflating: Images/9905.png
#   inflating: Images/9906.png
#  extracting: Images/9907.png
#   inflating: Images/9908.png
#  extracting: Images/9909.png
#  extracting: Images/991.png
#  extracting: Images/9910.png
#  extracting: Images/9911.png
#   inflating: Images/9912.png
#  extracting: Images/9913.png
#  extracting: Images/9914.png
#  extracting: Images/9915.png
#  extracting: Images/9916.png
#  extracting: Images/9917.png
#  extracting: Images/9918.png
#  extracting: Images/9919.png
#  extracting: Images/992.png
#   inflating: Images/9920.png
#   inflating: Images/9921.png
#  extracting: Images/9922.png
#  extracting: Images/9923.png
#  extracting: Images/9924.png
#  extracting: Images/9925.png
#  extracting: Images/9926.png
#  extracting: Images/9927.png
#  extracting: Images/9928.png
#   inflating: Images/9929.png
#  extracting: Images/993.png
#  extracting: Images/9930.png
#   inflating: Images/9931.png
#   inflating: Images/9932.png
#  extracting: Images/9933.png
#  extracting: Images/9934.png
#  extracting: Images/9935.png
#   inflating: Images/9936.png
#  extracting: Images/9937.png
#   inflating: Images/9938.png
#   inflating: Images/9939.png
#  extracting: Images/994.png
#  extracting: Images/9940.png
#  extracting: Images/9941.png
#  extracting: Images/9942.png
#   inflating: Images/9943.png
#  extracting: Images/9944.png
#   inflating: Images/9945.png
#  extracting: Images/9946.png
#  extracting: Images/9947.png
#  extracting: Images/9948.png
#  extracting: Images/9949.png
#  extracting: Images/995.png
#  extracting: Images/9950.png
#  extracting: Images/9951.png
#  extracting: Images/9952.png
#   inflating: Images/9953.png
#  extracting: Images/9954.png
#  extracting: Images/9955.png
#  extracting: Images/9956.png
#  extracting: Images/9957.png
#  extracting: Images/9958.png
#  extracting: Images/9959.png
#  extracting: Images/996.png
#  extracting: Images/9960.png
#  extracting: Images/9961.png
#   inflating: Images/9962.png
#  extracting: Images/9963.png
#   inflating: Images/9964.png
#  extracting: Images/9965.png
#   inflating: Images/9966.png
#   inflating: Images/9967.png
#  extracting: Images/9968.png
#  extracting: Images/9969.png
#  extracting: Images/997.png
#  extracting: Images/9970.png
#  extracting: Images/9971.png
#  extracting: Images/9972.png
#  extracting: Images/9973.png
#  extracting: Images/9974.png
#  extracting: Images/9975.png
#  extracting: Images/9976.png
#  extracting: Images/9977.png
#  extracting: Images/9978.png
#  extracting: Images/9979.png
#  extracting: Images/998.png
#  extracting: Images/9980.png
#  extracting: Images/9981.png
#  extracting: Images/9982.png
#  extracting: Images/9983.png
#  extracting: Images/9984.png
#  extracting: Images/9985.png
#  extracting: Images/9986.png
#  extracting: Images/9987.png
#  extracting: Images/9988.png
#  extracting: Images/9989.png
#  extracting: Images/999.png
#  extracting: Images/9990.png
#  extracting: Images/9991.png
#  extracting: Images/9992.png
#  extracting: Images/9993.png
#  extracting: Images/9994.png
#  extracting: Images/9995.png
#   inflating: Images/9996.png
#  extracting: Images/9997.png
#  extracting: Images/9998.png
#  extracting: Images/9999.png
#   inflating: data.csv

# %%
import os
import torchvision
import torch
def remove_noise(image):
    alpha = image[3, :,:]> 50
    alpha = alpha.type(torch.uint8)
    noise_filtered = torch.mul(alpha, image)
    return noise_filtered[:3,:,:]

def read_voc_images(voc_dir, n=-1,  is_train=True):
    """Read all VOC feature and label images."""
    files = [os.path.join(voc_dir, file) for file in os.listdir(voc_dir)]
    #files = files.sort()
    files = sorted(files, key=lambda i: int(os.path.splitext(os.path.basename(i))[0]))
    mode = torchvision.io.image.ImageReadMode.RGB_ALPHA
    features, labels = [], []
    for i, fname in enumerate(files):
        l = fname.split("/")
        if i==n: break
        try:
          img = remove_noise(torchvision.io.read_image(os.path.join(
            voc_dir, fname)))
        except:
          continue
        features.append(img)
        labels.append(int(l[-1][:-4]))
    return features, labels

# %%
import pandas as pd
data = pd.read_csv("data.csv")
f, l = read_voc_images("/content/Images")
names = list(data["Name"])

# %% [markdown]
# Veamos algunas imágenes del dataset.

# %%
#@markdown función show_images
from matplotlib import pyplot as plt
def show_images(imgs, num_rows, num_cols, titles=None, scale=1.5):
    """Plot a list of images.

    Defined in :numref:`sec_utils`"""
    figsize = (num_cols * scale, num_rows * scale)
    _, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    axes = axes.flatten()
    for i, (ax, img) in enumerate(zip(axes, imgs)):
        try:
            img = img.detach().numpy()
        except:
            pass
        ax.imshow(img)
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
        if titles:
            ax.set_title(titles[i])
    return axes

# %%
imgs = [img.permute(1,2,0) for img in f]
show_images(imgs, 2, 5, scale=2,titles = names);

# %% [markdown]
# Definimos un dataset personalizado para estas imágenes y cargamos con él un dataloader con 256 de tamaño de lote.

# %%
class FIFADataset(torch.utils.data.Dataset):
    def __init__(self, img_list, labels, names):
        super(FIFADataset, self).__init__()
        self.img_list = img_list
        self.labels = labels
        self.names = names
        self.transform = torchvision.transforms.Resize((64,64))

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        img = self.img_list[idx]
        l  = self.labels[idx]
        n  = self.names[idx]
        return self.transform(img.type(torch.float32)), l, n

# %%
fifa = FIFADataset(f,l,names)
batch_size = 256
data_iter = torch.utils.data.DataLoader(
    fifa, batch_size=batch_size,
    shuffle=True, num_workers=2)

# %% [markdown]
# ## El Generador
#
# El generador necesita mapear la variable de ruido $\mathbf z\in\mathbb R^d$, un vector de longitud-$d$, a una imagen RGB con un ancho y un alto de $64\times 64$. El bloque básico del generador contiene una capa de convolución transpuesta seguida de la normalización por lotes y la activación de ReLU.

# %%
from torch import nn
class G_block(nn.Module):
    def __init__(self, out_channels, in_channels=3, kernel_size=4, strides=2,
                 padding=1, **kwargs):
        super(G_block, self).__init__(**kwargs)
        self.conv2d_trans = nn.ConvTranspose2d(in_channels, out_channels,
                                kernel_size, strides, padding, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU()

    def forward(self, X):
        return self.activation(self.batch_norm(self.conv2d_trans(X)))

# %% [markdown]
# De forma predeterminada, la capa de convolución transpuesta utiliza un kernel $k_h = k_w = 4$, un stride $s_h = s_w = 2$ y un padding $p_h = p_w = 1$. Con una entrada de forma $n_h \times n_w = 16 \times 16$, el bloque generador duplicará el ancho y la altura de la entrada.
#
# $$
# \begin{aligned}
# n_h^{'} \times n_w^{'} &= [(n_h k_h - (n_h-1)(k_h-s_h)- 2p_h] \times [(n_w k_w - (n_w-1)(k_w-s_w)- 2p_w]\\
#   &= [(k_h + s_h (n_h-1)- 2p_h] \times [(k_w + s_w (n_w-1)- 2p_w]\\
#   &= [(4 + 2 \times (16-1)- 2 \times 1] \times [(4 + 2 \times (16-1)- 2 \times 1]\\
#   &= 32 \times 32 .\\
# \end{aligned}
# $$

# %%
x = torch.zeros((2, 3, 16, 16))
g_blk = G_block(20)
g_blk(x).shape
# Out:
# torch.Size([2, 20, 32, 32])

# %% [markdown]
# Si se cambia el kernel de la capa de convolución transpuesta a uno de $4\times 4$, un stride de 1 y un padding 0, aumentará cuatro veces el tamaño de una entrada de $1 \times 1$.

# %%
x = torch.zeros((2, 3, 1, 1))
g_blk = G_block(20, strides=1, padding=0)
g_blk(x).shape
# Out:
# torch.Size([2, 20, 4, 4])

# %% [markdown]
# El generador consiste en cuatro bloques básicos que aumentan el ancho y el alto de la entrada de 1 a 32. Al mismo tiempo, primero proyecta la variable latente en $64\times 8$ canales, y luego reduce a la mitad los canales cada vez. Por último, se utiliza una capa más de convolución transpuesta para generar la salida. Duplica aún más el ancho y la altura para que coincida con la forma deseada de $64\times 64$, y reduce el tamaño del canal a $3$. La función de activación tanh se aplica a los valores de salida del proyecto en el rango $(-1, 1)$.

# %%
n_G = 64
net_G = nn.Sequential(
    G_block(in_channels=100, out_channels=n_G*8,
            strides=1, padding=0),                  # Output: (64 * 8, 4, 4)
    G_block(in_channels=n_G*8, out_channels=n_G*4), # Output: (64 * 4, 8, 8)
    G_block(in_channels=n_G*4, out_channels=n_G*2), # Output: (64 * 2, 16, 16)
    G_block(in_channels=n_G*2, out_channels=n_G),   # Output: (64, 32, 32)
    nn.ConvTranspose2d(in_channels=n_G, out_channels=3,
                       kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh())  # Output: (3, 64, 64)

# %% [markdown]
# Generemos una variable latente de 100 dimensiones para verificar la forma de la salida del generador.

# %%
x = torch.zeros((1, 100, 1, 1))
net_G(x).shape
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## El Discriminador
#
# El discriminador es una red convolucional normal excepto que utiliza una Leaky ReLU como su función de activación. Dado $\alpha \in[0, 1]$, su definición es
#
# $$\textrm{leaky ReLU}(x) = \begin{cases}x & \text{if}\ x > 0\\ \alpha x &\text{otherwise}\end{cases}.$$
#
# Como puede verse, es la ReLU normal si $\alpha=0$, y una función identidad si $\alpha=1$. Para $\alpha \in (0, 1)$, Leaky ReLU es una función no lineal que proporciona una salida distinta de cero para una entrada negativa. Su objetivo es solucionar el problema de la "ReLU moribunda" en la que una neurona puede generar un valor negativo siempre y, por lo tanto, no puede hacer ningún progreso ya que el gradiente de ReLU es 0.

# %%
#@markdown funciones para graficar
import matplotlib.pyplot as plt
def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
    """Set the axes for matplotlib.

    Defined in :numref:`sec_calculus`"""
    axes.set_xlabel(xlabel), axes.set_ylabel(ylabel)
    axes.set_xscale(xscale), axes.set_yscale(yscale)
    axes.set_xlim(xlim),     axes.set_ylim(ylim)
    if legend:
        axes.legend(legend)
    axes.grid()

def plot(X, Y=None, xlabel=None, ylabel=None, legend=[], xlim=None,
         ylim=None, xscale='linear', yscale='linear',
         fmts=('-', 'm--', 'g-.', 'r:'), figsize=(3.5, 2.5), axes=None):
    """Plot data points.

    Defined in :numref:`sec_calculus`"""

    def has_one_axis(X):  # True if `X` (tensor or list) has 1 axis
        return (hasattr(X, "ndim") and X.ndim == 1 or isinstance(X, list)
                and not hasattr(X[0], "__len__"))

    if has_one_axis(X): X = [X]
    if Y is None:
        X, Y = [[]] * len(X), X
    elif has_one_axis(Y):
        Y = [Y]
    if len(X) != len(Y):
        X = X * len(Y)


    if axes is None: axes = plt.gca()
    axes.cla()
    for x, y, fmt in zip(X, Y, fmts):
        axes.plot(x,y,fmt) if len(x) else axes.plot(y,fmt)
    set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend)

# %%
alphas = [0, .2, .4, .6, .8, 1]
x = torch.arange(-2, 1, 0.1)
Y = [nn.LeakyReLU(alpha)(x).detach().numpy() for alpha in alphas]
plot(x.detach().numpy(), Y, 'x', 'y', alphas)

# %% [markdown]
# El bloque básico del discriminador es una capa de convolución seguida de una capa de normalización por lotes y una activación de Leaky ReLU. Los hiperparámetros de la capa de convolución son similares a la capa de convolución transpuesta en el bloque generador.

# %%
class D_block(nn.Module):
    def __init__(self, out_channels, in_channels=3, kernel_size=4, strides=2,
                padding=1, alpha=0.2, **kwargs):
        super(D_block, self).__init__(**kwargs)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size,
                                strides, padding, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.LeakyReLU(alpha, inplace=True)

    def forward(self, X):
        return self.activation(self.batch_norm(self.conv2d(X)))

# %% [markdown]
# Un bloque básico con la configuración predeterminada reducirá a la mitad el ancho y el alto de las entradas. Por ejemplo, dada una entrada de forma $n_h = n_w = 16$, con una forma de kernel $k_h = k_w = 4$, un stride $s_h = s_w = 2$ y un padding $p_h = p_w = 1$, la forma de salida será:
#
# $$
# \begin{aligned}
# n_h^{'} \times n_w^{'} &= \lfloor(n_h-k_h+2p_h+s_h)/s_h\rfloor \times \lfloor(n_w-k_w+2p_w+s_w)/s_w\rfloor\\
#   &= \lfloor(16-4+2\times 1+2)/2\rfloor \times \lfloor(16-4+2\times 1+2)/2\rfloor\\
#   &= 8 \times 8 .\\
# \end{aligned}
# $$

# %%
x = torch.zeros((1, 3, 16, 16))
d_blk = D_block(20)
d_blk(x).shape
# Out:
# torch.Size([1, 20, 8, 8])

# %% [markdown]
# El discriminador es un reflejo del generador.

# %%
n_D = 64
net_D = nn.Sequential(
    D_block(n_D),  # Output: (64, 32, 32)
    D_block(in_channels=n_D, out_channels=n_D*2),  # Output: (64 * 2, 16, 16)
    D_block(in_channels=n_D*2, out_channels=n_D*4),  # Output: (64 * 4, 8, 8)
    D_block(in_channels=n_D*4, out_channels=n_D*8),  # Output: (64 * 8, 4, 4)
    nn.Conv2d(in_channels=n_D*8, out_channels=1,
              kernel_size=4, bias=False))  # Output: (1, 1, 1)

# %% [markdown]
# It uses a convolution layer with output channel $1$ as the last layer to obtain a single prediction value.

# %%
x = torch.zeros((1, 3, 64, 64))
net_D(x).shape
# Out:
# torch.Size([1, 1, 1, 1])

# %% [markdown]
# ## Entrenamiento
#
# En comparación con el GAN básico que vimos más arriba, usamos la misma tasa de aprendizaje tanto para el generador como para el discriminador, ya que son similares entre sí. Además, cambiamos $\beta_1$ en Adam de $0.9$ a $0.5$. Disminuye la suavidad del momentum, la media móvil ponderada exponencialmente de los gradientes anteriores, para cuidar los gradientes que cambian rápidamente porque el generador y el discriminador luchan entre sí. Además, el ruido generado aleatoriamente `Z` es un tensor 4-D y estamos usando GPU para acelerar el cálculo.

# %%
def train(net_D, net_G, data_iter, num_epochs, lr, latent_dim,
          device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')):
    loss = nn.BCEWithLogitsLoss(reduction='sum')
    for w in net_D.parameters():
        nn.init.normal_(w, 0, 0.02)
    for w in net_G.parameters():
        nn.init.normal_(w, 0, 0.02)
    net_D, net_G = net_D.to(device), net_G.to(device)
    trainer_hp = {'lr': lr, 'betas': [0.5,0.999]}
    trainer_D = torch.optim.Adam(net_D.parameters(), **trainer_hp)
    trainer_G = torch.optim.Adam(net_G.parameters(), **trainer_hp)
    animator = Animator(xlabel='epoch', ylabel='loss',
                            xlim=[1, num_epochs], nrows=2, figsize=(5, 5),
                            legend=['discriminator', 'generator'])
    animator.fig.subplots_adjust(hspace=0.3)
    for epoch in range(1, num_epochs + 1):
        # Train one epoch
        timer = Timer()
        metric = Accumulator(3)  # loss_D, loss_G, num_examples
        for X, _,_ in data_iter:
            batch_size = X.shape[0]
            Z = torch.normal(0, 1, size=(batch_size, latent_dim, 1, 1))
            X, Z = X.to(device), Z.to(device)
            metric.add(update_D(X, Z, net_D, net_G, loss, trainer_D),
                       update_G(Z, net_D, net_G, loss, trainer_G),
                       batch_size)
        # Show generated examples
        Z = torch.normal(0, 1, size=(21, latent_dim, 1, 1), device=device)
        # Normalize the synthetic data to N(0, 1)
        fake_x = net_G(Z).permute(0, 2, 3, 1) / 2 + 0.5
        imgs = torch.cat(
            [torch.cat([
                fake_x[i * 7 + j].cpu().detach() for j in range(7)], dim=1)
             for i in range(len(fake_x)//7)], dim=0)
        animator.axes[1].cla()
        animator.axes[1].imshow(imgs)
        # Show the losses
        loss_D, loss_G = metric[0] / metric[2], metric[1] / metric[2]
        animator.add(epoch, (loss_D, loss_G))
    print(f'loss_D {loss_D:.3f}, loss_G {loss_G:.3f}, '
          f'{metric[2] / timer.stop():.1f} examples/sec on {str(device)}')

# %% [markdown]
# Entrenamos el modelo con una pequeña cantidad de épocas solo para demostración. Para un mejor rendimiento, la variable num_epochs se puede establecer en un número mayor.

# %%
latent_dim, lr, num_epochs = 100, 0.005, 40
train(net_D, net_G, data_iter, num_epochs, lr, latent_dim)
# Out:
# loss_D 0.369, loss_G 5.125, 728.2 examples/sec on cuda

# %% [markdown]
# ## Predicción
#
# Una vez entrenada la red, se pueden generar imágenes aleatorias al muestrear un vector latente Z y pasarlo por el generador.

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
Z = torch.normal(0, 1, size=(21, latent_dim, 1, 1), device=device)
fake_x = net_G(Z).permute(0, 2, 3, 1) / 2 + 0.5
imgs = torch.cat(
            [torch.cat([
                fake_x[i * 7 + j].cpu().detach() for j in range(7)], dim=1)
             for i in range(len(fake_x)//7)], dim=0)
plt.imshow(imgs)
